# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")
sns.set_palette("pastel")

from sklearn.linear_model import LinearRegression, Ridge
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.pipeline import Pipeline

from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# # Clean and Merge Data

# %%
df = pd.read_csv('wr_stats.csv')

# df = pd.concat([te_stats, wr_stats])

# clean columns
df.columns = df.columns.str.lower()
df['player'] = df['player'].apply(lambda x: ' '.join(x.split()[:-1]))
df['firstName'] = df.player.str.split().str[0]
df['lastName'] = df.player.str.split().str[1]
df.yds = pd.to_numeric(df.yds.str.replace(',', ''))

df
# Out:
#       rank                player  rec  tgt   yds   y/r  lg  20+  td  att  \
# 0        1           Tyreek Hill   87  137  1479  17.0  75   55  12   22
# 1        2         Antonio Brown  104  168  1297  12.5  78   33  15    0
# 2        3         Davante Adams  111  169  1386  12.5  57   33  13    0
# 3        4       DeAndre Hopkins  115  163  1572  13.7  49   36  11    1
# 4        5           Julio Jones  113  170  1677  14.8  58   37   8    2
# ...    ...                   ...  ...  ...   ...   ...  ..  ...  ..  ...
# 1507   445       Braylon Sanders    2    3    17   8.5  13    0   0    0
# 1508   446  Ihmir Smith-Marsette    1    4    15  15.0  15    0   0    1
# 1509   447          Deonte Harty    2    2    13   6.5   9    0   0    0
# 1510   448       KaVontae Turpin    1    2     9   9.0   9    0   0    3
# 1511   449        Chester Rogers    0    0     0   0.0   0    0   0    0
#
#       yds.1  td.1  fl   g   fpts  fpts/g    own  year firstName  \
# 0       151     1   0  16  241.0    15.1  99.9%  2018    Tyreek
# 1         0     0   0  15  219.7    14.6   0.2%  2018   Antonio
# 2         0     0   0  15  218.6    14.6  99.9%  2018   Davante
# 3        -7     0   2  16  218.5    13.7  97.1%  2018   DeAndre
# 4        12     0   2  16  212.9    13.3   7.2%  2018     Julio
# ...     ...   ...  ..  ..    ...     ...    ...   ...       ...
# 1507      0     0   1   2   -0.3    -0.2   0.0%  2022   Braylon
# 1508     -1     0   1   4   -0.6    -0.2   0.0%  2022     Ihmir
# 1509      0     0   1   4   -0.7    -0.2   0.3%  2022    Deonte
# 1510     17     0   2  17   -1.4    -0.1   0.2%  2022  KaVontae
# 1511      0     0   1   3   -2.0    -0.7   0.0%  2022   Chester
#
#             lastName
# 0               Hill
# 1              Brown
# 2              Adams
# 3            Hopkins
# 4              Jones
# ...              ...
# 1507         Sanders
# 1508  Smith-Marsette
# 1509           Harty
# 1510          Turpin
# 1511          Rogers
#
# [1512 rows x 20 columns]

# %%
def clean_file(df, year):
    new_df = df.copy()
    new_df.Player = new_df.Player.str.replace('[*+]', '', regex = True)
    new_df['firstName'] = new_df.Player.str.split().str[0]
    new_df['lastName'] = new_df.Player.str.split().str[1]
    new_df['year'] = year
    new_df = new_df[['Tm', 'Age', 'firstName', 'lastName', 'year']]
    
    return new_df

# %%
df_18 = pd.read_csv('receiver_stats_2018.txt')
df_clean_18 = clean_file(df_18, 2018)

df_19 = pd.read_csv('receiver_stats_2019.txt')
df_clean_19 = clean_file(df_19, 2019)

df_20 = pd.read_csv('receiver_stats_2020.txt')
df_clean_20 = clean_file(df_20, 2020)

df_21 = pd.read_csv('receiver_stats_2021.txt')
df_clean_21 = clean_file(df_21, 2021)

df_22 = pd.read_csv('receiver_stats_2022.txt')
df_clean_22 = clean_file(df_22, 2022)

# %%
# concat and merge dataframes
df = df.copy()
df_combined = pd.concat([df_clean_18, df_clean_19, df_clean_20, df_clean_21, df_clean_22], ignore_index = True)
df_merged = pd.merge(df, df_combined, on = ['firstName', 'lastName', 'year'], how = 'inner')

# create experience variable


# filter down to running backs who play
df_merged = df_merged[(df_merged.tgt > 50) & (df_merged.fpts > 0)]
df_merged.sort_values(by  = 'fpts', ascending = False).head()
# Out:
#      rank         player  rec  tgt   yds   y/r  lg  20+  td  att  ...  fl   g  \
# 643     1    Cooper Kupp  145  191  1947  13.4  59   57  16    4  ...   0  17
# 644     2   Deebo Samuel   77  121  1405  18.2  83   53   6   59  ...   2  16
# 428     1  Davante Adams  115  149  1374  11.9  56   34  18    0  ...   1  14
# 429     2    Tyreek Hill   87  135  1276  14.7  75   38  15   13  ...   0  15
# 0       1    Tyreek Hill   87  137  1479  17.0  75   55  12   22  ...   0  16
#
#       fpts  fpts/g    own  year firstName  lastName   Tm Age
# 643  294.5    17.3  99.9%  2021    Cooper      Kupp  LAR  28
# 644  262.0    16.4  98.6%  2021     Deebo    Samuel  SFO  25
# 428  243.4    17.4  99.9%  2020   Davante     Adams  GNB  28
# 429  241.9    16.1  99.9%  2020    Tyreek      Hill  KAN  26
# 0    241.0    15.1  99.9%  2018    Tyreek      Hill  KAN  24
#
# [5 rows x 22 columns]

# %%
df_merged[df_merged.player == 'DeAndre Hopkins']
# Out:
#      rank           player  rec  tgt   yds   y/r  lg  20+  td  att  ...  fl  \
# 3       4  DeAndre Hopkins  115  163  1572  13.7  49   36  11    1  ...   2
# 220     9  DeAndre Hopkins  104  150  1165  11.2  43   24   7    2  ...   0
# 436    10  DeAndre Hopkins  115  160  1407  12.2  60   35   6    1  ...   2
# 679    39  DeAndre Hopkins   42   64   572  13.6  55   13   8    0  ...   0
# 913    49  DeAndre Hopkins   64   96   717  11.2  33   10   3    0  ...   1
#
#       g   fpts  fpts/g    own  year firstName  lastName   Tm Age
# 3    16  218.5    13.7  97.1%  2018   DeAndre   Hopkins  HOU  26
# 220  15  165.5    11.0  97.1%  2019   DeAndre   Hopkins  HOU  27
# 436  16  172.8    10.8  97.1%  2020   DeAndre   Hopkins  ARI  28
# 679  10  105.2    10.5  97.1%  2021   DeAndre   Hopkins  ARI  29
# 913   9   87.7     9.7  97.1%  2022   DeAndre   Hopkins  ARI  30
#
# [5 rows x 22 columns]

# %% [markdown]
# # Create Pred DF

# %%
# create dataframe that will contain target variable
df_pvt = df_merged.pivot_table(values = 'fpts/g', columns = 'year', index = 'player').fillna(0).reset_index()
df_pvt.head()
# Out:
# year          player  2018  2019  2020  2021  2022
# 0         A.J. Brown   0.0  10.3  12.7   9.1  12.4
# 1         A.J. Green  11.5   0.0   4.0   6.4   0.0
# 2     Adam Humphries   7.0   0.0   0.0   2.3   0.0
# 3       Adam Thielen  12.1   0.0  12.0  10.2   6.5
# 4      Albert Wilson   0.0   3.6   0.0   0.0   0.0

# %%
pred_df = df_merged.loc[df_merged.year == 2021, ['player', 'fpts/g', 'Age']].reset_index(drop = True)

# merge in 2022 stats
pred_df = pd.merge(pred_df, df_pvt, on = 'player', how = 'left').fillna(0)
pred_df.columns = ['player', 'fpts/g', 'Age' ,'2018', '2019', '2020', '2021', 'fpts/g_2022']
pred_df = pred_df.loc[(pred_df['fpts/g'] > 5) & (pred_df['fpts/g_2022'] > 5),['player', 'fpts/g', 'Age', 'fpts/g_2022']]\
                 .reset_index(drop = True)

pred_df
# Out:
#                    player  fpts/g  Age  fpts/g_2022
# 0             Cooper Kupp    17.3   28         14.0
# 1            Deebo Samuel    16.4   25          8.6
# 2           Ja'Marr Chase    13.2   21         12.0
# 3        Justin Jefferson    13.1   22         14.2
# 4           Davante Adams    13.8   29         13.9
# 5              Mike Evans    11.8   28          9.9
# 6             Tyreek Hill    10.9   27         13.1
# 7            Stefon Diggs    10.7   28         12.4
# 8           Mike Williams    10.7   27          8.7
# 9           Tyler Lockett    10.5   29          9.6
# 10        Diontae Johnson    10.5   25          5.6
# 11            CeeDee Lamb     9.6   22         11.4
# 12           Keenan Allen     9.5   29          9.8
# 13    Michael Pittman Jr.     8.9   24          7.3
# 14            Tee Higgins    10.4   22          9.9
# 15           Chris Godwin    10.3   25          7.9
# 16          Brandin Cooks     8.9   28          6.8
# 17          Jaylen Waddle     8.9   23         10.8
# 18         Darnell Mooney     8.2   24          5.6
# 19      Amon-Ra St. Brown     8.6   22         10.1
# 20         Terry McLaurin     8.0   26          8.9
# 21         Marquise Brown     8.5   24          7.4
# 22           Amari Cooper     9.0   27          9.9
# 23           Adam Thielen    10.2   31          6.5
# 24         Christian Kirk     7.7   25          9.3
# 25          DeVonta Smith     7.2   23          9.4
# 26             A.J. Brown     9.1   24         12.4
# 27             Tyler Boyd     7.3   27          6.9
# 28          Brandon Aiyuk     6.7   23          8.8
# 29            K.J. Osborn     6.4   24          5.6
# 30        DeAndre Hopkins    10.5   29          9.7
# 31          Jakobi Meyers     6.5   25          8.1
# 32           Allen Lazard     7.3   26          7.7
# 33           Russell Gage     7.5   25          5.6
# 34       Courtland Sutton     5.4   26          6.4
# 35  Donovan Peoples-Jones     5.4   22          6.2

# %% [markdown]
# # Data Exploration

# %%
plt.figure()
sns.boxplot(data = df_merged, x = 'Age', y = 'fpts/g')
plt.show()

# %%
plt.figure()
sns.regplot(data = pred_df, x = 'fpts/g', y='fpts/g_2022')
plt.show()

# %%
sns.heatmap(pred_df.corr().round(2), annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Modeling

# %%
predictors = ['fpts/g', 'Age']
target = 'fpts/g_2022'

X = pred_df[predictors]
y = pred_df[target]


# split data into train/test seet
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = .8, random_state = 42)


# scale data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

# %% [markdown]
# # Random Forest Regressor

# %%
# create model
rf = RandomForestRegressor(n_estimators = 100, max_depth = 5, min_samples_split = 6)
rf.fit(X_train_scaled, y_train)
# Out:
# RandomForestRegressor(max_depth=5, min_samples_split=6)

# %% [markdown]
# # Linear Regression

# %%
reg = LinearRegression()
reg.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Polynomial Regression

# %%
poly = PolynomialFeatures(degree = 2, include_bias = False)
X_train_scaled_poly = poly.fit_transform(X_train_scaled)

poly_reg = LinearRegression()
poly_reg.fit(X_train_scaled_poly, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Evaluate Models Above

# %%
# make predictions
rf_predictions = rf.predict(X_test_scaled)
reg_predictions = reg.predict(X_test_scaled)

# fit test dataframe with polynomial features before making prediction
X_test_scaled_poly = poly.fit_transform(X_test_scaled)
poly_predictions = poly_reg.predict(X_test_scaled_poly)


# evalate average error
rf_error = mean_absolute_error(y_test, rf_predictions)
reg_error = mean_absolute_error(y_test, reg_predictions)
poly_error = mean_absolute_error(y_test, poly_predictions)

# %%
print(rf_error)
print(reg_error)
print(poly_error)
# Out:
# 2.4528156024531027
# 1.5946999135678117
# 2.0605791677964675
