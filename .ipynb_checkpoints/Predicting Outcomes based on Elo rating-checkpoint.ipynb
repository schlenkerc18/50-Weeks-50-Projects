# %%
import numpy as np
import pandas as pd

import seaborn as sns

# %%
df = pd.read_csv('./data/nfl_elo.csv')
df.head()
# Out:
#          date  season  neutral playoff team1 team2  elo1_pre  elo2_pre  \
# 0  1920-09-26    1920        0     NaN   RII   STP  1503.947  1300.000
# 1  1920-10-03    1920        0     NaN   CBD   PTQ  1504.688  1300.000
# 2  1920-10-03    1920        0     NaN   CHI   MUT  1368.333  1300.000
# 3  1920-10-03    1920        0     NaN   RII   MUN  1516.108  1478.004
# 4  1920-10-03    1920        0     NaN   DAY   COL  1493.002  1504.908
#
#    elo_prob1  elo_prob2  ...  qb2_game_value  qb1_value_post  qb2_value_post  \
# 0   0.824651   0.175349  ...             NaN             NaN             NaN
# 1   0.825267   0.174733  ...             NaN             NaN             NaN
# 2   0.682986   0.317014  ...             NaN             NaN             NaN
# 3   0.644171   0.355829  ...             NaN             NaN             NaN
# 4   0.575819   0.424181  ...             NaN             NaN             NaN
#
#    qbelo1_post qbelo2_post score1  score2  quality  importance  total_rating
# 0          NaN         NaN     48       0      NaN         NaN           NaN
# 1          NaN         NaN     48       0      NaN         NaN           NaN
# 2          NaN         NaN     20       0      NaN         NaN           NaN
# 3          NaN         NaN     45       0      NaN         NaN           NaN
# 4          NaN         NaN     14       0      NaN         NaN           NaN
#
# [5 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['date', 'season', 'neutral', 'playoff', 'team1', 'team2', 'elo1_pre',
#        'elo2_pre', 'elo_prob1', 'elo_prob2', 'elo1_post', 'elo2_post',
#        'qbelo1_pre', 'qbelo2_pre', 'qb1', 'qb2', 'qb1_value_pre',
#        'qb2_value_pre', 'qb1_adj', 'qb2_adj', 'qbelo_prob1', 'qbelo_prob2',
#        'qb1_game_value', 'qb2_game_value', 'qb1_value_post', 'qb2_value_post',
#        'qbelo1_post', 'qbelo2_post', 'score1', 'score2', 'quality',
#        'importance', 'total_rating'],
#       dtype='object')

# %%
df.drop(['date', 'playoff', 'elo1_post' ,'elo2_post', 'qb1_adj', 'qb2_adj', 'qb1_game_value', 'qb2_game_value', 
         'qb1_value_post', 'qb2_value_post', 'qbelo1_post' , 'qbelo2_post', 'qb1', 'qb2'], axis = 1, inplace = True)
df.head()
# Out:
#    season  neutral team1 team2  elo1_pre  elo2_pre  elo_prob1  elo_prob2  \
# 0    1920        0   RII   STP  1503.947  1300.000   0.824651   0.175349
# 1    1920        0   CBD   PTQ  1504.688  1300.000   0.825267   0.174733
# 2    1920        0   CHI   MUT  1368.333  1300.000   0.682986   0.317014
# 3    1920        0   RII   MUN  1516.108  1478.004   0.644171   0.355829
# 4    1920        0   DAY   COL  1493.002  1504.908   0.575819   0.424181
#
#    qbelo1_pre  qbelo2_pre  qb1_value_pre  qb2_value_pre  qbelo_prob1  \
# 0         NaN         NaN            NaN            NaN          NaN
# 1         NaN         NaN            NaN            NaN          NaN
# 2         NaN         NaN            NaN            NaN          NaN
# 3         NaN         NaN            NaN            NaN          NaN
# 4         NaN         NaN            NaN            NaN          NaN
#
#    qbelo_prob2  score1  score2  quality  importance  total_rating
# 0          NaN      48       0      NaN         NaN           NaN
# 1          NaN      48       0      NaN         NaN           NaN
# 2          NaN      20       0      NaN         NaN           NaN
# 3          NaN      45       0      NaN         NaN           NaN
# 4          NaN      14       0      NaN         NaN           NaN

# %%
df.columns
# Out:
# Index(['season', 'neutral', 'team1', 'team2', 'elo1_pre', 'elo2_pre',
#        'elo_prob1', 'elo_prob2', 'qbelo1_pre', 'qbelo2_pre', 'qb1_value_pre',
#        'qb2_value_pre', 'qbelo_prob1', 'qbelo_prob2', 'score1', 'score2',
#        'quality', 'importance', 'total_rating'],
#       dtype='object')

# %%
df = df[df.season > 1980]
df.head()
# Out:
#       season  neutral team1 team2  elo1_pre  elo2_pre  elo_prob1  elo_prob2  \
# 6788    1981        0    TB   MIN  1406.844  1500.060   0.459483   0.540517
# 6789    1981        0   DEN   OAK  1521.128  1646.467   0.414028   0.585972
# 6790    1981        0    NE   IND  1558.953  1457.599   0.722643   0.277357
# 6791    1981        0   NYG   PHI  1392.378  1604.258   0.300376   0.699624
# 6792    1981        0   LAR   TEN  1562.771  1569.795   0.582668   0.417332
#
#        qbelo1_pre   qbelo2_pre  qb1_value_pre  qb2_value_pre  qbelo_prob1  \
# 6788  1399.748069  1509.447526     103.389980      45.089928     0.464581
# 6789  1507.372471  1646.418709     103.172340      83.751010     0.395053
# 6790  1568.971841  1450.854773      84.114320     103.168153     0.726431
# 6791  1397.419192  1601.681408      71.634224      94.924866     0.302353
# 6792  1569.723364  1576.769224      79.304654      72.899521     0.565516
#
#       qbelo_prob2  score1  score2  quality  importance  total_rating
# 6788     0.535419      21      13     21.0         NaN           NaN
# 6789     0.604947       9       7     84.0         NaN           NaN
# 6790     0.273569      28      29     51.0         NaN           NaN
# 6791     0.697647      10      24     44.0         NaN           NaN
# 6792     0.434484      20      27     80.0         NaN           NaN

# %%
df[df.score1 > df.score2]
# Out:
#              date  season  neutral playoff team1 team2     elo1_pre  \
# 11476  2001-09-09    2001        0     NaN   JAX   PIT  1502.466000
# 11478  2001-09-09    2001        0     NaN    GB   DET  1556.165000
# 11479  2001-09-09    2001        0     NaN    SF   ATL  1456.597000
# 11483  2001-09-09    2001        0     NaN   LAC   WSH  1362.011000
# 11484  2001-09-09    2001        0     NaN   BAL   CHI  1652.017000
# ...           ...     ...      ...     ...   ...   ...          ...
# 17084  2022-01-16    2021        0       w    TB   PHI  1670.677134
# 17086  2022-01-16    2021        0       w    KC   PIT  1687.590474
# 17087  2022-01-17    2021        0       w   LAR   ARI  1615.789160
# 17091  2022-01-23    2021        0       d    KC   BUF  1699.470145
# 17093  2022-01-30    2021        0       c   LAR    SF  1651.615346
#
#           elo2_pre  elo_prob1  elo_prob2  ...  qb2_game_value  qb1_value_post  \
# 11476  1520.072000   0.567786   0.432214  ...      -22.365624      117.694318
# 11478  1509.406000   0.655507   0.344493  ...     -130.547706      108.557885
# 11479  1404.460000   0.662464   0.337536  ...       47.290247      180.272095
# 11483  1510.163000   0.382568   0.617432  ...     -125.907091      115.501723
# 11484  1419.710000   0.847023   0.152977  ...       19.209892      143.068852
# ...            ...        ...        ...  ...             ...             ...
# 17084  1511.939214   0.783798   0.216202  ...       74.221952      249.882409
# 17086  1524.594936   0.787922   0.212078  ...      153.731715      273.771767
# 17087  1516.586992   0.720154   0.279846  ...      -42.847876      179.870436
# 17091  1683.332367   0.614689   0.385311  ...      434.101420      308.598809
# 17093  1621.465562   0.633608   0.366392  ...      197.148060      204.657956
#
#        qb2_value_post  qbelo1_post  qbelo2_post score1  score2  quality  \
# 11476       78.875142  1549.885266  1471.208379     21       3     56.0
# 11478       22.848535  1562.212351  1464.341977     28       6     55.0
# 11479       25.474642  1473.375733  1394.891579     16      13     17.0
# 11483       73.593460  1460.121049  1510.562512     30       3     49.0
# 11484       66.411744  1639.675692  1441.115733     17       6     71.0
# ...               ...          ...          ...    ...     ...      ...
# 17084      155.957975  1649.547292  1488.834431     31      15     83.0
# 17086      131.333275  1687.450699  1504.938873     42      21     85.0
# 17087      195.699541  1615.165080  1497.234857     34      11     76.0
# 17091      291.477231  1700.324756  1644.036577     42      36    100.0
# 17093      125.373817  1644.929010  1621.968494     20      17     96.0
#
#        importance  total_rating
# 11476         NaN           NaN
# 11478         NaN           NaN
# 11479         NaN           NaN
# 11483         NaN           NaN
# 11484         NaN           NaN
# ...           ...           ...
# 17084       100.0          92.0
# 17086       100.0          93.0
# 17087       100.0          88.0
# 17091       100.0         100.0
# 17093       100.0          98.0
#
# [3179 rows x 33 columns]

# %%
df['teamOneWin'] = (df.score1 > df.score2).replace({True: 1, False: 0})
df['teamTwoWin'] = (df.score2 > df.score1).replace({True: 1, False: 0})
df.head()
# Out:
#              date  season  neutral playoff team1 team2  elo1_pre  elo2_pre  \
# 11476  2001-09-09    2001        0     NaN   JAX   PIT  1502.466  1520.072
# 11477  2001-09-09    2001        0     NaN   DAL    TB  1449.774  1569.911
# 11478  2001-09-09    2001        0     NaN    GB   DET  1556.165  1509.406
# 11479  2001-09-09    2001        0     NaN    SF   ATL  1456.597  1404.460
# 11480  2001-09-09    2001        0     NaN   TEN   MIA  1603.825  1568.090
#
#        elo_prob1  elo_prob2  ...  qb2_value_post  qbelo1_post  qbelo2_post  \
# 11476   0.567786   0.432214  ...       78.875142  1549.885266  1471.208379
# 11477   0.421311   0.578689  ...       87.616566  1408.063875  1587.631342
# 11478   0.655507   0.344493  ...       22.848535  1562.212351  1464.341977
# 11479   0.662464   0.337536  ...       25.474642  1473.375733  1394.891579
# 11480   0.641039   0.358961  ...       75.461739  1578.752208  1553.790512
#
#        score1 score2 quality  importance  total_rating  teamOneWin  teamTwoWin
# 11476      21      3    56.0         NaN           NaN           1           0
# 11477       6     10    48.0         NaN           NaN           0           1
# 11478      28      6    55.0         NaN           NaN           1           0
# 11479      16     13    17.0         NaN           NaN           1           0
# 11480      23     31    78.0         NaN           NaN           0           1
#
# [5 rows x 35 columns]

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
df.groupby(['team1', 'season'])

# %%
df.columns
# Out:
# Index(['date', 'season', 'neutral', 'playoff', 'team1', 'team2', 'elo1_pre',
#        'elo2_pre', 'elo_prob1', 'elo_prob2', 'elo1_post', 'elo2_post',
#        'qbelo1_pre', 'qbelo2_pre', 'qb1', 'qb2', 'qb1_value_pre',
#        'qb2_value_pre', 'qb1_adj', 'qb2_adj', 'qbelo_prob1', 'qbelo_prob2',
#        'qb1_game_value', 'qb2_game_value', 'qb1_value_post', 'qb2_value_post',
#        'qbelo1_post', 'qbelo2_post', 'score1', 'score2', 'quality',
#        'importance', 'total_rating'],
#       dtype='object')

# %%
np.unique(df.team1)
# Out:
# array(['AKR', 'ARI', 'ATL', 'BAL', 'BBA', 'BCL', 'BDA', 'BFF', 'BKN',
#        'BRL', 'BUF', 'BYK', 'CAR', 'CBD', 'CHB', 'CHI', 'CHL', 'CHT',
#        'CIB', 'CIN', 'CLE', 'CLI', 'COL', 'CRA', 'CRP', 'CST', 'CTI',
#        'DAL', 'DAY', 'DEN', 'DET', 'DHR', 'DPN', 'DTI', 'DTX', 'DUL',
#        'DWL', 'ECG', 'ELY', 'FTW', 'FYJ', 'GAR', 'GB', 'GUN', 'HAM',
#        'HOU', 'HRT', 'IND', 'JAX', 'KC', 'KCB', 'KEN', 'LAC', 'LAR',
#        'LDA', 'LOG', 'LOU', 'MIA', 'MIL', 'MIN', 'MNM', 'MNN', 'MSA',
#        'MUN', 'NAA', 'NE', 'NG1', 'NO', 'NYA', 'NYG', 'NYJ', 'NYY', 'OAK',
#        'OOR', 'PHI', 'PIT', 'PRV', 'PTB', 'PUL', 'RAC', 'RCH', 'RCK',
#        'RED', 'RIC', 'RII', 'ROS', 'SEA', 'SEN', 'SF', 'SIS', 'SLA',
#        'STG', 'TB', 'TEN', 'THO', 'TOL', 'TOR', 'UAP', 'WGC', 'WSH',
#        'ZAN'], dtype=object)
